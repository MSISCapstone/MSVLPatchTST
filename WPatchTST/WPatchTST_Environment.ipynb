# %% [markdown]
# <a href="https://colab.research.google.com/github/MSISCapstone/CSPatchTST/blob/mouryavs/WPatchTST/WPatchTST_Environment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone -b mouryavs https://github.com/MSISCapstone/CSPatchTST.git
# Out:
# Cloning into 'CSPatchTST'...
# remote: Enumerating objects: 663, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 663 (delta 57), reused 52 (delta 38), pack-reused 578 (from 1)
# Receiving objects: 100% (663/663), 42.11 MiB | 20.72 MiB/s, done.
# Resolving deltas: 100% (335/335), done.
# Filtering content: 100% (2/2), 221.27 MiB | 68.89 MiB/s, done.

# %%
cd /content/CSPatchTST/WPatchTST
# Out:
# /content/CSPatchTST/WPatchTST

# %%
ls
# Out:
# environment.yml  requirements.txt

# %%
# %pip install -r requirements.txt

# %%
import torch
print(torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# 2.9.0+cu126
# CUDA available: True
# GPU: Tesla T4
