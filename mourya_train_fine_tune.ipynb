# %% [markdown]
# <a href="https://colab.research.google.com/github/MSISCapstone/MSVLPatchTST/blob/mourya_fine_tune/mourya_train_fine_tune.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone your MSVLPatchTST repository
# !git clone https://github.com/MSISCapstone/MSVLPatchTST.git
# %cd MSVLPatchTST

# Checkout fine-tune branch
# !git checkout mourya_fine_tune
# Out:
# Cloning into 'MSVLPatchTST'...
# remote: Enumerating objects: 1253, done.
# remote: Counting objects: 100% (199/199), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 1253 (delta 143), reused 149 (delta 128), pack-reused 1054 (from 1)
# Receiving objects: 100% (1253/1253), 63.09 MiB | 45.02 MiB/s, done.
# Resolving deltas: 100% (724/724), done.
# Filtering content: 100% (2/2), 221.27 MiB | 118.38 MiB/s, done.
# /content/MSVLPatchTST
# Branch 'mourya_fine_tune' set up to track remote branch 'mourya_fine_tune' from 'origin'.
# Switched to a new branch 'mourya_fine_tune'

# %%
# Install PyTorch (Colab usually has it, but we ensure correct version)
# !pip install torch torchvision torchaudio --quiet

# Install other required libraries
# !pip install numpy pandas matplotlib scikit-learn tqdm einops --quiet

# %%
import torch
import numpy
import pandas
import sklearn
import einops
print("All core libraries installed successfully.")
# Out:
# All core libraries installed successfully.

# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# CUDA Available: True
# Device: NVIDIA A100-SXM4-40GB

# %%
# !ls datasets
# Out:
# electricity  ETT-small	exchange_rate  illness	traffic  weather

# %%
# !ls main/scripts
# Out:
# compare_summaries.py  weather_msvl_test.sh	weather_original_training.sh
# patch_len_configs     weather_msvl_training.sh
# setup.sh	      weather_original_test.sh

# %%
# !sed -n '1,200p' main/scripts/weather_msvl_training.sh
# Out:
# #!/bin/bash
#
# # MSVLPatchTST for Weather Forecasting
# # Multi-Scale Variable-Length PatchTST with exact parameters as baseline
# # Uses new architecture from MSVLPatchTST module
#
# # Parse command line arguments
# # Usage option 1: Pass config file
# #   ./weather_msvl_training.sh patch_len_configs/ps_config_1.txt
# # Usage option 2: Pass individual parameters
# #   ./weather_msvl_training.sh 8 4 16 8
#
# if [ -f "$1" ]; then
#     # Config file provided
#     CONFIG_FILE="$1"
#     PATCH_STRIDE_PARAMS=$(cat "$CONFIG_FILE")
#     echo "Using config file: $CONFIG_FILE"
#     echo "Parameters: $PATCH_STRIDE_PARAMS"
#
#     # Extract values for folder naming
#     patch_len_short=$(echo "$PATCH_STRIDE_PARAMS" | grep -oP '(?<=--patch_len_short )\d+')
#     stride_short=$(echo "$PATCH_STRIDE_PARAMS" | grep -oP '(?<=--stride_short )\d+')
#     patch_len_long=$(echo "$PATCH_STRIDE_PARAMS" | grep -oP '(?<=--patch_len_long )\d+')
# ...

# %%
# !bash main/scripts/weather_msvl_training.sh 16 8 16 8
# Out:
# Using individual parameters:
# Short channel: patch_len=16, stride=8, weight=1.5
# Long channel: patch_len=16, stride=8, weight=0.5
# Running in Google Colab, skipping venv activation
# Running MSVLPatchTST (Multi-Scale Variable-Length PatchTST)
# Parameters: short[p16_s8_w1.5] long[p16_s8_w0.5]
# ...
# MSVLPatchTST
# seq_len=336, pred_len=96
# Short channel: patch_len=16, stride=8, weight=1.5
# Long channel: patch_len=16, stride=8, weight=0.5
# ...
# Training completed for pred_len=96
# ...
#
# ...
# All experiments completed! Check /content/MSVLPatchTST/output/MSVLPatchTST/ for results
# ...

# %%
# !bash main/scripts/weather_msvl_training.sh 16 8 12 6
# Out:
# Using individual parameters:
# Short channel: patch_len=16, stride=8, weight=1.5
# Long channel: patch_len=12, stride=6, weight=0.5
# Running in Google Colab, skipping venv activation
# Running MSVLPatchTST (Multi-Scale Variable-Length PatchTST)
# Parameters: short[p16_s8_w1.5] long[p12_s6_w0.5]
# ...
# MSVLPatchTST
# seq_len=336, pred_len=96
# Short channel: patch_len=16, stride=8, weight=1.5
# Long channel: patch_len=12, stride=6, weight=0.5
# ...
# Training completed for pred_len=96
# ...
#
# ...
# All experiments completed! Check /content/MSVLPatchTST/output/MSVLPatchTST/ for results
# ...

# %%
# !bash main/scripts/weather_msvl_training.sh 24 12 16 8
# Out:
# Using individual parameters:
# Short channel: patch_len=24, stride=12, weight=1.5
# Long channel: patch_len=16, stride=8, weight=0.5
# Running in Google Colab, skipping venv activation
# Running MSVLPatchTST (Multi-Scale Variable-Length PatchTST)
# Parameters: short[p24_s12_w1.5] long[p16_s8_w0.5]
# ...
# MSVLPatchTST
# seq_len=336, pred_len=96
# Short channel: patch_len=24, stride=12, weight=1.5
# Long channel: patch_len=16, stride=8, weight=0.5
# ...
# Training completed for pred_len=96
# ...
#
# ...
# All experiments completed! Check /content/MSVLPatchTST/output/MSVLPatchTST/ for results
# ...

# %%
# !bash main/scripts/weather_msvl_training.sh 16 8 16 8
# Out:
# Using individual parameters:
# Short channel: patch_len=16, stride=8, weight=1.5
# Long channel: patch_len=16, stride=8, weight=0.5
# Running in Google Colab, skipping venv activation
# Running MSVLPatchTST (Multi-Scale Variable-Length PatchTST)
# Parameters: short[p16_s8_w1.5] long[p16_s8_w0.5]
# ...
# MSVLPatchTST
# seq_len=336, pred_len=96
# Short channel: patch_len=16, stride=8, weight=1.5
# Long channel: patch_len=16, stride=8, weight=0.5
# ...
# Training completed for pred_len=96
# ...
#
# ...
# All experiments completed! Check /content/MSVLPatchTST/output/MSVLPatchTST/ for results
# ...
